# %% [markdown]
# <div dir="rtl">
#
# # منصّة تعليم إلكتروني مصغّرة – دفتر الشروح
#
# ## <strong>1. المشكلة (السياق والمشكل)</strong>
#
# في السياق الجامعي والمهني، يواجه الطلاب والمتعلّمون نقصًا في منصّات بسيطة وسريعة وسهلة الاستخدام للوصول إلى الدروس، أو متابعة تكوين قصير، أو اكتشاف محتوى تعليمي جديد.
#
# المنصّات الموجودة غالبًا ما تكون معقّدة أو تتطلّب حسابات متقدمة، وهو ما لا يناسب التكوينات القصيرة أو الهاكاثونات.
#
# ### <strong>🎯 هدف المشروع</strong>
# إنشاء **منصّة تعليم إلكتروني مصغّرة (Mini e-Learning)** تسمح للطلاب بالوصول إلى عدة دورات، عرض محتوى كل دورة بالتفصيل (نص + فيديو تجريبي)، مع مساحة طالب بسيطة تشمل تسجيل دخول خفيف.
#
# ## <strong>2. الجمهور المستهدف</strong>
#
# ### <strong>🎯 الطلاب والمتعلّمون</strong>
# - يرغبون في وصول سريع لدروس قصيرة ومنظّمة.
# - يحتاجون إلى رؤية واضحة للمواد.
# - يريدون مساحة شخصية بسيطة.
#
# ### <strong>🎓 الأساتذة والمكوّنون</strong>
# - يرغبون في نشر دروس مختصرة (3–4 وحدات).
# - يحتاجون إلى أداة بسيطة لعرض محتوى الدروس.
#
# ## <strong>3. أهداف المشروع</strong>
#
# - إنشاء منصّة تعليمية بسيطة وسهلة الاستخدام.
# - عرض قائمة الدروس مع العنوان والوصف والصورة.
# - عرض محتوى الدرس بالتفصيل.
# - دمج فيديو تجريبي داخل صفحة الدرس.
# - توفير تسجيل دخول بسيط للطالب.
# - إعداد Backend بسيط بخدمات `/courses` و `/students`.
# - تصميم واجهة حديثة ومتجاوبة.
# - توفير نموذج تفاعلي عبر **Figma**.
#
# ## <strong>4. الخصائص المدمجة</strong>
#
# ### <strong>1️⃣ الصفحة الرئيسية</strong>
# - عرض تقديمي للمنصّة.
# - شعار بسيط (مثل: <em>تعلم بسرعة. تعلّم بذكاء.</em>).
# - قسم "دروسنا" مع معاينات سريعة.
#
# ### <strong>2️⃣ قائمة الدروس</strong>
#
# قائمة بـ 3–4 دورات، كل دورة تحتوي على:
# - عنوان
# - صورة
# - وصف مختصر
# - زر "عرض الدرس"
#
# <strong>واجهة Backend:</strong>
# `GET /courses`
#
# ### <strong>3️⃣ صفحة تفاصيل الدرس</strong>
#
# تحتوي على:
# - صورة أو بانر
# - وصف تفصيلي
# - فيديو تجريبي مدمج
# - قسم "ماذا ستتعلّم"
# - زر "ابدأ" أو "تابع"
#
# <strong>واجهة Backend:</strong>
# `GET /courses/:id`
#
# ### <strong>4️⃣ مساحة الطالب – تسجيل الدخول</strong>
#
# نظام بسيط:
# - صفحة تسجيل دخول
# - بدون حماية متقدمة (localStorage + API mock)
# - بعد الدخول → صفحة الملف الشخصي
#   - اسم الطالب
#   - آخر درس تمت زيارته
#   - التقدم (وهمي)
#
# <strong>واجهات Backend:</strong>
# - `POST /students/login`
# - `GET /students/:id`
#
# ### <strong>5️⃣ صفحة الملف الشخصي</strong>
#
# تحتوي على:
# - صورة رمزية + اسم
# - الدروس المتابعة
# - التقدم
# - زر "تسجيل الخروج"
#
# ### <strong>6️⃣ Backend مصغّر – API JSON</strong>
#
# Back-end بسيط لـ:
# - عرض الدروس
# - عرض التفاصيل
# - تسجيل دخول الطالب
# - (اختياري) تخزين التقدم
#
# <strong>الـ API الأساسية:</strong>
# - `/courses`
# - `/courses/:id`
# - `/students`
# - `/students/login`
#
# ## <strong>5. المخرجات (Deliverables)</strong>
#
# ### <strong>📌 نموذج Figma</strong>
# - نماذج تفاعلية
# - واجهة مستخدم واضحة
# - تنقّل: <em>الرئيسية → الدروس → التفاصيل → تسجيل الدخول → الملف الشخصي</em>
#
# ### <strong>📌 واجهة Frontend جاهزة</strong>
# - HTML/CSS أو React أو Vue أو Flutter Web
# - تصميم متجاوب
# - واجهة حديثة
#
# ### <strong>📌 Backend جاهز</strong>
# - API بسيطة
# - بيانات JSON
# - المسارات الأساسية
#
# ### <strong>📌 عرض (Demo)</strong>
# - تقديم 5–7 دقائق
# - شرح الفكرة
# - عرض النموذج + الموقع
#
# ## <strong>6. المتطلبات التقنية</strong>
#
# ### <strong>📌 Frontend</strong>
# - صفحات: الرئيسية، الدروس، تفاصيل الدرس، تسجيل الدخول، الملف الشخصي
# - تصميم متجاوب
#
# ### <strong>📌 Backend</strong>
# - API REST
# - بيانات JSON (ساكنة أو ديناميكية)
#
# ### <strong>📌 قاعدة بيانات بسيطة</strong>
# - JSON أو SQLite أو MySQL
#
# <strong>الجداول المقترحة:</strong>
# - `courses`
# - `students`
# - (اختياري) `progress`
#
# ### <strong>📌 تصميم الواجهة</strong>
# - تصميم حديث ومبسّط
# - ألوان متناسقة
# - أيقونات خفيفة
#
# ## <strong>7. الخلاصة</strong>
#
# مشروع **منصّة تعليم إلكتروني مصغرّة** هو مزيج ممتاز بين:
#
# - **Frontend** (واجهة مستخدم، هيكلة الصفحات، التصميم)
# - **Backend** (API بسيطة لكن وظيفية)
# - **النمذجة الأولية (Prototyping)**
# - **العمل الجماعي**
#
# يتيح إنشاء منصّة صغيرة، حديثة، واضحة، وفعّالة يمكن إنجازها بالكامل خلال هاكاثون.
#
# </div>
