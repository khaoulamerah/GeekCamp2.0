# %% [markdown]
# #  منصّة تعليم إلكتروني مصغّرة – دفتر الشروط
#
# ---
#
# ## **1. المشكلة (السياق والمشكل)**
#
# في السياق الجامعي والمهني، يواجه الطلاب والمتعلّمون نقصًا في منصّات بسيطة وسريعة وسهلة الاستخدام للوصول إلى الدروس، أو متابعة تكوين قصير، أو اكتشاف محتوى تعليمي جديد.
#
# المنصّات الموجودة غالبًا ما تكون معقّدة أو تتطلّب حسابات متقدّمة، وهو ما لا يناسب التكوينات القصيرة أو الهاكاثونات.
#
# ### 🎯 **هدف المشروع**
# إنشاء **منصّة تعليم إلكتروني مصغّرة (Mini e-Learning)** تسمح للطلاب بالوصول إلى عدة دورات، عرض محتوى كل دورة بالتفصيل (نص + فيديو تجريبي)، مع مساحة طالب بسيطة تشمل تسجيل دخول خفيف.
#
# ---
#
# ## **2. الجمهور المستهدف**
#
# ### 🎯 **الطلاب والمتعلّمون**
# - يرغبون في وصول سريع لدروس قصيرة ومنظّمة.
# - يحتاجون إلى رؤية واضحة للمواد.
# - يريدون مساحة شخصية بسيطة.
#
# ### 🎓 **الأساتذة والمكوّنون**
# - يرغبون في نشر دروس مختصرة (3–4 وحدات).
# - يحتاجون إلى أداة بسيطة لعرض محتوى الدروس.
#
# ---
#
# ## **3. أهداف المشروع**
#
# - إنشاء منصّة تعليمية بسيطة وسهلة الاستخدام.
# - عرض قائمة الدروس مع العنوان والوصف والصورة.
# - عرض محتوى الدرس بالتفصيل.
# - دمج فيديو تجريبي داخل صفحة الدرس.
# - توفير تسجيل دخول بسيط للطالب.
# - إعداد Backend بسيط بخدمات `/courses` و `/students`.
# - تصميم واجهة حديثة ومتجاوبة.
# - توفير نموذج تفاعلي عبر **Figma**.
#
# ---
#
# ## **4. الخصائص المدمجة**
#
# ### **1️⃣ الصفحة الرئيسية**
# - عرض تقديمي للمنصّة.
# - شعار بسيط (مثل: *تعلم بسرعة. تعلّم بذكاء.*).
# - قسم “دروسنا” مع معاينات سريعة.
#
# ---
#
# ### **2️⃣ قائمة الدروس**
#
# قائمة بـ 3–4 دورات، كل دورة تحتوي على:
# - عنوان
# - صورة
# - وصف مختصر
# - زر “عرض الدرس”
#
# **واجهة Backend:**
# `GET /courses`
#
# ---
#
# ### **3️⃣ صفحة تفاصيل الدرس**
#
# تحتوي على:
# - صورة أو بانر
# - وصف تفصيلي
# - فيديو تجريبي مدمج
# - قسم “ماذا ستتعلّم”
# - زر “ابدأ” أو “تابع”
#
# **واجهة Backend:**
# `GET /courses/:id`
#
# ---
#
# ### **4️⃣ مساحة الطالب – تسجيل الدخول**
#
# نظام بسيط:
# - صفحة تسجيل دخول
# - بدون حماية متقدمة (localStorage + API mock)
# - بعد الدخول → صفحة الملف الشخصي
#   - اسم الطالب
#   - آخر درس تمت زيارته
#   - التقدم (وهمي)
#
# **واجهات Backend:**
# - `POST /students/login`
# - `GET /students/:id`
#
# ---
#
# ### **5️⃣ صفحة الملف الشخصي**
#
# تحتوي على:
# - صورة رمزية + اسم
# - الدروس المتابعة
# - التقدم
# - زر “تسجيل الخروج”
#
# ---
#
# ### **6️⃣ Backend مصغّر – API JSON**
#
# Back-end بسيط لـ:
# - عرض الدروس
# - عرض التفاصيل
# - تسجيل دخول الطالب
# - (اختياري) تخزين التقدم
#
# **الـ API الأساسية:**
# - `/courses`
# - `/courses/:id`
# - `/students`
# - `/students/login`
#
# ---
#
# ## **5. المخرجات (Deliverables)**
#
# ### **📌 نموذج Figma**
# - نماذج تفاعلية
# - واجهة مستخدم واضحة
# - تنقّل: *الرئيسية → الدروس → التفاصيل → تسجيل الدخول → الملف الشخصي*
#
# ### **📌 واجهة Frontend جاهزة**
# - HTML/CSS أو React أو Vue أو Flutter Web
# - تصميم متجاوب
# - واجهة حديثة
#
# ### **📌 Backend جاهز**
# - API بسيطة
# - بيانات JSON
# - المسارات الأساسية
#
# ### **📌 عرض (Demo)**
# - تقديم 5–7 دقائق
# - شرح الفكرة
# - عرض النموذج + الموقع
#
# ---
#
# ## **6. المتطلبات التقنية**
#
# ### **📌 Frontend**
# - صفحات: الرئيسية، الدروس، تفاصيل الدرس، تسجيل الدخول، الملف الشخصي
# - تصميم متجاوب
#
# ### **📌 Backend**
# - API REST
# - بيانات JSON (ساكنة أو ديناميكية)
#
# ### **📌 قاعدة بيانات بسيطة**
# - JSON أو SQLite أو MySQL
#
# **الجداول المقترحة:**
